# %% [markdown]
# # Web Scraping
#
# In order to practice web scraping, I'll start by scraping the web page https://www.popvortex.com/music/charts/top-100-songs.php. I'll then be able to integrate these songs into the recommender.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'https://www.popvortex.com/music/charts/top-100-songs.php'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
# print(soup.prettify())

# %% [markdown]
# ### Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
# we first pick up the songs names

for i in soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite'):
    print(i.get_text())
# Out:
# Margaritaville
# Come Monday
# Rich Men North of Richmond
# I Remember Everything (feat. Kacey Musgraves)
# Dream Weaver
# Paint The Town Red
# All Star
# Cheeseburger In Paradise
# Changes In Latitudes, Changes In Attitudes
# Lil Boo Thang
# A Pirate Looks at Forty
# Fast Car
# Love Is Alive
# Used To Be Young
# Cruel Summer
# Last Time I Saw You
# It's Five O'Clock Somewhere (Live)
# Need A Favor
# Son of a Son of a Sailor
# Dance The Night
# Last Night
# Try That In A Small Town
# White Horse
# I Want to go Home
# Walkin' On the Sun
# I'm a Believer
# 90 some Chevy
# Watermelon Moonshine
# Fins
# Save Me (with Lainey Wilson)
# All Star
# Flowers
# Thinkin’ Bout Me
# Walkin' On the Sun
# Lose Control
# Rockstar
# vampire
# Religiously
# Used To Be Young
# Southern Cross (Live)
# Walkin' On the Sun
# Dreams
# Aint Gotta Dollar
# Why Don't We Get Drunk
# Calm Down
# Indiana Jones
# Love You Anyway
# It's Five O'Clock Somewhere (with Jimmy Buffett)
# What Was I Made For? [From The Motion Picture "Barbie"]
# Latinos For Trump
# Volcano
# Have You Ever Seen the Rain
# Trip Around the Sun
# Keep Going Up
# Brown Eyed Girl (Live)
# How You Remind Me
# Forever Young
# Southern Cross
# TRUCK BED
# Beat You There
# Son Of A Sinner
# Something in the Orange (Z&E's Version)
# Far Away
# Photograph
# Enter Sandman
# Whiteboyz
# Single Soon
# Tennessee Whiskey
# Bury Me in Georgia (Single Edit)
# In Your Love
# Daylight
# Hard to Say I'm Sorry / Get Away
# He Went to Paris
# Everything I Love
# Snooze
# I'll Stand By You
# Dial Drunk
# We Didn’t Start The Fire
# Come Monday
# Anti-Hero
# You're the Inspiration
# Rhiannon
# august
# Gypsy
# One Particular Harbour
# A Symptom Of Being Human
# Hey Driver (feat. The War and Treaty)
# 90 Some Chevy (Live)
# Ive Got to Get Sober
# bad idea right?
# Thought You Should Know
# I'm a Believer
# Bring Me to Life
# I Want To Go Home (live)
# Knee Deep (feat. Jimmy Buffett) [Greatest Hits Version]
# Barbie World (with Aqua)
# Everywhere
# Unstoppable
# Good Good

# %%
# we put them in a new list

songs = []
for i in soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite'):
    song = i.get_text()
    songs.append(song)
    
songs
# Out:
# ['Margaritaville',
#  'Come Monday',
#  'Rich Men North of Richmond',
#  'I Remember Everything (feat. Kacey Musgraves)',
#  'Dream Weaver',
#  'Paint The Town Red',
#  'All Star',
#  'Cheeseburger In Paradise',
#  'Changes In Latitudes, Changes In Attitudes',
#  'Lil Boo Thang',
#  'A Pirate Looks at Forty',
#  'Fast Car',
#  'Love Is Alive',
#  'Used To Be Young',
#  'Cruel Summer',
#  'Last Time I Saw You',
#  "It's Five O'Clock Somewhere (Live)",
#  'Need A Favor',
#  'Son of a Son of a Sailor',
#  'Dance The Night',
#  'Last Night',
#  'Try That In A Small Town',
#  'White Horse',
#  'I Want to go Home',
#  "Walkin' On the Sun",
#  "I'm a Believer",
#  '90 some Chevy',
#  'Watermelon Moonshine',
#  'Fins',
#  'Save Me (with Lainey Wilson)',
#  'All Star',
#  'Flowers',
#  'Thinkin’ Bout Me',
#  "Walkin' On the Sun",
#  'Lose Control',
#  'Rockstar',
#  'vampire',
#  'Religiously',
#  'Used To Be Young',
#  'Southern Cross (Live)',
#  "Walkin' On the Sun",
#  'Dreams',
#  'Aint Gotta Dollar',
#  "Why Don't We Get Drunk",
#  'Calm Down',
#  'Indiana Jones',
#  'Love You Anyway',
#  "It's Five O'Clock Somewhere (with Jimmy Buffett)",
#  'What Was I Made For? [From The Motion Picture "Barbie"]',
#  'Latinos For Trump',
#  'Volcano',
#  'Have You Ever Seen the Rain',
#  'Trip Around the Sun',
#  'Keep Going Up',
#  'Brown Eyed Girl (Live)',
#  'How You Remind Me',
#  'Forever Young',
#  'Southern Cross',
#  'TRUCK BED',
#  'Beat You There',
#  'Son Of A Sinner',
#  "Something in the Orange (Z&E's Version)",
#  'Far Away',
#  'Photograph',
#  'Enter Sandman',
#  'Whiteboyz',
#  'Single Soon',
#  'Tennessee Whiskey',
#  'Bury Me in Georgia (Single Edit)',
#  'In Your Love',
#  'Daylight',
#  "Hard to Say I'm Sorry / Get Away",
#  'He Went to Paris',
#  'Everything I Love',
#  'Snooze',
#  "I'll Stand By You",
#  'Dial Drunk',
#  'We Didn’t Start The Fire',
#  'Come Monday',
#  'Anti-Hero',
#  "You're the Inspiration",
#  'Rhiannon',
#  'august',
#  'Gypsy',
#  'One Particular Harbour',
#  'A Symptom Of Being Human',
#  'Hey Driver (feat. The War and Treaty)',
#  '90 Some Chevy (Live)',
#  'Ive Got to Get Sober',
#  'bad idea right?',
#  'Thought You Should Know',
#  "I'm a Believer",
#  'Bring Me to Life',
#  'I Want To Go Home (live)',
#  'Knee Deep (feat. Jimmy Buffett) [Greatest Hits Version]',
#  'Barbie World (with Aqua)',
#  'Everywhere',
#  'Unstoppable',
#  'Good Good']

# %%
# then we do the same for the singers

singers = []
for i in soup.select('div.chart-content.col-xs-12.col-sm-8 > p > em'):
    singer = i.get_text()
    singers.append(singer)
    
singers
# Out:
# ['Jimmy Buffett',
#  'Jimmy Buffett',
#  'Oliver Anthony Music',
#  'Zach Bryan',
#  'Gary Wright',
#  'Doja Cat',
#  'Smash Mouth',
#  'Jimmy Buffett',
#  'Jimmy Buffett',
#  'Paul Russell',
#  'Jimmy Buffett',
#  'Luke Combs',
#  'Gary Wright',
#  'Miley Cyrus',
#  'Taylor Swift',
#  'Nicki Minaj',
#  'Jimmy Buffett',
#  'Jelly Roll',
#  'Jimmy Buffett',
#  'Dua Lipa',
#  'Morgan Wallen',
#  'Jason Aldean',
#  'Chris Stapleton',
#  'Oliver Anthony Music',
#  'Smash Mouth',
#  'Smash Mouth',
#  'Oliver Anthony Music',
#  'Lainey Wilson',
#  'Jimmy Buffett',
#  'Jelly Roll',
#  'Smash Mouth',
#  'Miley Cyrus',
#  'Morgan Wallen',
#  'Smash Mouth',
#  'Teddy Swims',
#  'Nickelback',
#  'Olivia Rodrigo',
#  'Bailey Zimmerman',
#  'Miley Cyrus',
#  'Jimmy Buffett',
#  'Smash Mouth',
#  'Fleetwood Mac',
#  'Oliver Anthony Music',
#  'Jimmy Buffett',
#  'Rema & Selena Gomez',
#  'Wayland',
#  'Luke Combs',
#  'Alan Jackson',
#  'Billie Eilish',
#  'Trump Latinos',
#  'Jimmy Buffett',
#  'Creedence Clearwater Revival',
#  'Jimmy Buffett & Martina McBride',
#  'Timbaland, Nelly Furtado & Justin Timberlake',
#  'Jimmy Buffett',
#  'Nickelback',
#  'Rod Stewart',
#  'Crosby, Stills & Nash',
#  'HARDY',
#  'Will Dempsey',
#  'Jelly Roll',
#  'Zach Bryan',
#  'Nickelback',
#  'Nickelback',
#  'Metallica',
#  'Tom MacDonald & Adam Calhoun',
#  'Selena Gomez',
#  'Chris Stapleton',
#  'Kane Brown',
#  'Tyler Childers',
#  'David Kushner',
#  'Chicago',
#  'Jimmy Buffett',
#  'Morgan Wallen',
#  'SZA',
#  'Pretenders',
#  'Noah Kahan & Post Malone',
#  'Fall Out Boy',
#  'Jimmy Buffett',
#  'Taylor Swift',
#  'Chicago',
#  'Fleetwood Mac',
#  'Taylor Swift',
#  'Fleetwood Mac',
#  'Jimmy Buffett',
#  'Shinedown',
#  'Zach Bryan',
#  'Oliver Anthony Music',
#  'Oliver Anthony Music',
#  'Olivia Rodrigo',
#  'Morgan Wallen',
#  'Smash Mouth',
#  'Evanescence',
#  'Oliver Anthony Music',
#  'Zac Brown Band',
#  'Nicki Minaj & Ice Spice',
#  'Fleetwood Mac',
#  'Sia',
#  'USHER, Summer Walker & 21 Savage']

# %%
# then we create a dataframe

top100 = pd.DataFrame({"title":songs,
                       "artist":singers,
                      })

# %%
top100
# Out:
#                                                 title  \
# 0                                      Margaritaville
# 1                                         Come Monday
# 2                          Rich Men North of Richmond
# 3       I Remember Everything (feat. Kacey Musgraves)
# 4                                        Dream Weaver
# ..                                                ...
# 94  Knee Deep (feat. Jimmy Buffett) [Greatest Hits...
# 95                           Barbie World (with Aqua)
# 96                                         Everywhere
# 97                                        Unstoppable
# 98                                          Good Good
#
#                               artist
# 0                      Jimmy Buffett
# 1                      Jimmy Buffett
# 2               Oliver Anthony Music
# 3                         Zach Bryan
# 4                        Gary Wright
# ..                               ...
# 94                    Zac Brown Band
# 95           Nicki Minaj & Ice Spice
# 96                     Fleetwood Mac
# 97                               Sia
# 98  USHER, Summer Walker & 21 Savage
#
# [99 rows x 2 columns]

# %% [markdown]
# ### Now we add another lists of hot songs on the internet and scrape them too:

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Eurovision_Song_Contest_winners'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.find("table", class_="wikitable")
# table

# %%
countries = []
songs = []
artists = []

# looping through each row in the table, skipping the header row
for row in table.find_all("tr"):
    # finding all table data cells in the row
    cells = row.find_all("td")   
    # checking if there are at least 3 cells (country, song, artist)
    if len(cells) >= 3:
        country = cells[0].get_text(strip=True)
        song = cells[1].get_text(strip=True)
        artist = cells[2].get_text(strip=True)
        # adding data to respective lists
        countries.append(country)
        songs.append(song)
        artists.append(artist)

# creating a DataFrame from the lists
eurovision = pd.DataFrame({
    "Country": countries,
    "Song": songs,
    "Artist": artists
})


eurovision
# Out:
#         Country                  Song            Artist
# 0   Switzerland             "Refrain"         Lys Assia
# 1   Netherlands        "Net als toen"     Corry Brokken
# 2        France     "Dors, mon amour"     André Claveau
# 3   Netherlands          "Een beetje"    Teddy Scholten
# 4        France         "Tom Pillibi"  Jacqueline Boyer
# ..          ...                   ...               ...
# 65       Israel                 "Toy"             Netta
# 66  Netherlands              "Arcade"   Duncan Laurence
# 67        Italy       "Zitti e buoni"          Måneskin
# 68      Ukraine  "Stefania"(Стефанія)  Kalush Orchestra
# 69       Sweden              "Tattoo"            Loreen
#
# [70 rows x 3 columns]

# %%
eurovision['Song']=eurovision['Song'].str.replace(r"\"",'',regex=True)

# %%
eurovision = eurovision[['Song','Artist']]

# %%
eurovision
# Out:
#                   Song            Artist
# 0              Refrain         Lys Assia
# 1         Net als toen     Corry Brokken
# 2      Dors, mon amour     André Claveau
# 3           Een beetje    Teddy Scholten
# 4          Tom Pillibi  Jacqueline Boyer
# ..                 ...               ...
# 65                 Toy             Netta
# 66              Arcade   Duncan Laurence
# 67       Zitti e buoni          Måneskin
# 68  Stefania(Стефанія)  Kalush Orchestra
# 69              Tattoo            Loreen
#
# [70 rows x 2 columns]

# %%
eurovision.columns = ['title','artist']

# %%
eurovision
# Out:
#                  title            artist
# 0              Refrain         Lys Assia
# 1         Net als toen     Corry Brokken
# 2      Dors, mon amour     André Claveau
# 3           Een beetje    Teddy Scholten
# 4          Tom Pillibi  Jacqueline Boyer
# ..                 ...               ...
# 65                 Toy             Netta
# 66              Arcade   Duncan Laurence
# 67       Zitti e buoni          Måneskin
# 68  Stefania(Стефанія)  Kalush Orchestra
# 69              Tattoo            Loreen
#
# [70 rows x 2 columns]

# %% [markdown]
# ### Now we create a new dataframe with all the scraped songs

# %%
top_songs = pd.concat([top100, eurovision], axis=0).reset_index()

# %%
top_songs = top_songs.drop(columns='index')

# %%
top_songs
# Out:
#                                              title                artist
# 0                                   Margaritaville         Jimmy Buffett
# 1                                      Come Monday         Jimmy Buffett
# 2                       Rich Men North of Richmond  Oliver Anthony Music
# 3    I Remember Everything (feat. Kacey Musgraves)            Zach Bryan
# 4                                     Dream Weaver           Gary Wright
# ..                                             ...                   ...
# 164                                            Toy                 Netta
# 165                                         Arcade       Duncan Laurence
# 166                                  Zitti e buoni              Måneskin
# 167                             Stefania(Стефанія)      Kalush Orchestra
# 168                                         Tattoo                Loreen
#
# [169 rows x 2 columns]

# %% [markdown]
# # Recommender
#
# Now we create the recommender thanks the 10000 songs list we already created.

# %%
songs_features = pd.read_pickle('/Users/damiencombe/Desktop/IH-Labs/Project files/songs_features.pkl')

# %%
songs_features
# Out:
#                            track.name                    name  \
# 0                Like a Rolling Stone               Bob Dylan
# 1             Smells Like Teen Spirit                 Nirvana
# 2      A Day In The Life - Remastered             The Beatles
# 3              Good Vibrations (Mono)          The Beach Boys
# 4                      Johnny B Goode             Chuck Berry
# ...                               ...                     ...
# 10925                 Into The Valley                   Skids
# 10926              Tonight's Da Night                  Redman
# 10927                        Figure 8               FKA twigs
# 10928                   Like An Angel  The Mighty Lemon Drops
# 10929                    Come Dancing               The Kinks
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      3AhXZa8sUQht0UEdBJgpGc         0.482   0.721    0    -6.839     1
# 1      3oTlkzk1OtrhH8wBAduVEi         0.485   0.863    1    -9.027     1
# 2      3ZFBeIyP41HhnALjxWy1pR         0.364   0.457    4   -14.162     0
# 3      5Qt4Cc66g24QWwGP3YYV9y         0.398   0.413    1   -10.934     1
# 4      7MH2ZclofPlTrZOkPzZKhK         0.518   0.756   10   -10.851     1
# ...                       ...           ...     ...  ...       ...   ...
# 10925  2QSD3K3b3BJ8DPhGhQfDPW         0.332   0.707    7   -12.698     1
# 10926  49XnDVsYOHgV4gFZeCojKj         0.464   0.749    6    -8.564     1
# 10927  5Y9IIH8Xmo1nuk0gfFjc4Q         0.694   0.710    2    -9.793     1
# 10928  0ya0JYEFoXNviB8RMeHDtW         0.332   0.800    1    -9.746     1
# 10929  32y1kRg6IF3f6jpkHxzFoK         0.499   0.763    7   -11.617     1
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.0321      0.731000  ...    0.1890    0.557   95.263
# 1           0.0495      0.000012  ...    0.1380    0.767  116.835
# 2           0.0675      0.290000  ...    0.9220    0.175  163.219
# 3           0.0388      0.082200  ...    0.0891    0.331  133.574
# 4           0.0915      0.735000  ...    0.3170    0.968  166.429
# ...            ...           ...  ...       ...      ...      ...
# 10925       0.0361      0.000012  ...    0.1100    0.652  144.815
# 10926       0.4800      0.224000  ...    0.3510    0.879  181.121
# 10927       0.3400      0.527000  ...    0.0697    0.415  119.964
# 10928       0.0326      0.000368  ...    0.0850    0.832  149.240
# 10929       0.0704      0.244000  ...    0.0828    0.895  152.677
#
#                  type                      id  \
# 0      audio_features  3AhXZa8sUQht0UEdBJgpGc
# 1      audio_features  3oTlkzk1OtrhH8wBAduVEi
# 2      audio_features  3ZFBeIyP41HhnALjxWy1pR
# 3      audio_features  5Qt4Cc66g24QWwGP3YYV9y
# 4      audio_features  7MH2ZclofPlTrZOkPzZKhK
# ...               ...                     ...
# 10925  audio_features  2QSD3K3b3BJ8DPhGhQfDPW
# 10926  audio_features  49XnDVsYOHgV4gFZeCojKj
# 10927  audio_features  5Y9IIH8Xmo1nuk0gfFjc4Q
# 10928  audio_features  0ya0JYEFoXNviB8RMeHDtW
# 10929  audio_features  32y1kRg6IF3f6jpkHxzFoK
#
#                                         uri  \
# 0      spotify:track:3AhXZa8sUQht0UEdBJgpGc
# 1      spotify:track:3oTlkzk1OtrhH8wBAduVEi
# 2      spotify:track:3ZFBeIyP41HhnALjxWy1pR
# 3      spotify:track:5Qt4Cc66g24QWwGP3YYV9y
# 4      spotify:track:7MH2ZclofPlTrZOkPzZKhK
# ...                                     ...
# 10925  spotify:track:2QSD3K3b3BJ8DPhGhQfDPW
# 10926  spotify:track:49XnDVsYOHgV4gFZeCojKj
# 10927  spotify:track:5Y9IIH8Xmo1nuk0gfFjc4Q
# 10928  spotify:track:0ya0JYEFoXNviB8RMeHDtW
# 10929  spotify:track:32y1kRg6IF3f6jpkHxzFoK
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3AhXZa8sUQht...
# 1      https://api.spotify.com/v1/tracks/3oTlkzk1Otrh...
# 2      https://api.spotify.com/v1/tracks/3ZFBeIyP41Hh...
# 3      https://api.spotify.com/v1/tracks/5Qt4Cc66g24Q...
# 4      https://api.spotify.com/v1/tracks/7MH2ZclofPlT...
# ...                                                  ...
# 10925  https://api.spotify.com/v1/tracks/2QSD3K3b3BJ8...
# 10926  https://api.spotify.com/v1/tracks/49XnDVsYOHgV...
# 10927  https://api.spotify.com/v1/tracks/5Y9IIH8Xmo1n...
# 10928  https://api.spotify.com/v1/tracks/0ya0JYEFoXNv...
# 10929  https://api.spotify.com/v1/tracks/32y1kRg6IF3f...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3AhX...      369600
# 1      https://api.spotify.com/v1/audio-analysis/3oTl...      300977
# 2      https://api.spotify.com/v1/audio-analysis/3ZFB...      337413
# 3      https://api.spotify.com/v1/audio-analysis/5Qt4...      219147
# 4      https://api.spotify.com/v1/audio-analysis/7MH2...      160893
# ...                                                  ...         ...
# 10925  https://api.spotify.com/v1/audio-analysis/2QSD...      199467
# 10926  https://api.spotify.com/v1/audio-analysis/49Xn...      201800
# 10927  https://api.spotify.com/v1/audio-analysis/5Y9I...      183040
# 10928  https://api.spotify.com/v1/audio-analysis/0ya0...      222160
# 10929  https://api.spotify.com/v1/audio-analysis/32y1...      234853
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 10925               4
# 10926               4
# 10927               4
# 10928               4
# 10929               4
#
# [10930 rows x 21 columns]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("/Users/damiencombe/Desktop/IH-Labs/Project files/secrets-Copy1","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
name = 'ziggy'

# %%
result_song= sp.search(q=name,type='track',limit=1)

# %%
# result_song

# %%
# result_song['tracks']['items']

# %%
song = result_song['tracks']['items'][0] #index because it's a list 
song['id']
# Out:
# '5IyL3XOaRPpTgxVjRIAxXU'

# %%
track_id = song['id']

# %%
audio_features = sp.audio_features(track_id)

# %%
audio_features
# Out:
# [{'danceability': 0.515,
#   'energy': 0.554,
#   'key': 7,
#   'loudness': -11.616,
#   'mode': 1,
#   'speechiness': 0.0784,
#   'acousticness': 0.0478,
#   'instrumentalness': 0,
#   'liveness': 0.219,
#   'valence': 0.509,
#   'tempo': 80.146,
#   'type': 'audio_features',
#   'id': '5IyL3XOaRPpTgxVjRIAxXU',
#   'uri': 'spotify:track:5IyL3XOaRPpTgxVjRIAxXU',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IyL3XOaRPpTgxVjRIAxXU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IyL3XOaRPpTgxVjRIAxXU',
#   'duration_ms': 193880,
#   'time_signature': 4}]

# %%
import pickle
scaler=pickle.load(open('/Users/damiencombe/Desktop/IH-Labs/Project files/scaler.pkl','rb'))

# %%
df_audio_features = pd.DataFrame(audio_features)

# %%
df_audio_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.515   0.554    7   -11.616     1       0.0784        0.0478
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0                 0     0.219    0.509  80.146  audio_features
#
#                        id                                   uri  \
# 0  5IyL3XOaRPpTgxVjRIAxXU  spotify:track:5IyL3XOaRPpTgxVjRIAxXU
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5IyL3XOaRPpT...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5IyL...       193880
#
#    time_signature
# 0               4

# %%
import numpy as np
df_audio_features = df_audio_features.select_dtypes(include = np.number)

# %%
df_audio_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.515   0.554    7   -11.616     1       0.0784        0.0478
#
#    instrumentalness  liveness  valence   tempo  duration_ms  time_signature
# 0                 0     0.219    0.509  80.146       193880               4

# %%
from sklearn.preprocessing import StandardScaler

scaled = scaler.transform(df_audio_features)

# %%
scaled
# Out:
# array([[-0.34166979, -0.26438778,  0.47063174, -0.63792314,  0.66264974,
#          0.02328885, -0.79216473, -0.43790041,  0.18377811, -0.27189117,
#         -1.46290429, -0.48213078,  0.21374741]])

# %%
df_audio_features = pd.DataFrame(scaled,columns=df_audio_features.columns)

# %%
df_audio_features
# Out:
#    danceability    energy       key  loudness     mode  speechiness  \
# 0      -0.34167 -0.264388  0.470632 -0.637923  0.66265     0.023289
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.792165           -0.4379  0.183778 -0.271891 -1.462904    -0.482131
#
#    time_signature
# 0        0.213747

# %%
from pandas import json_normalize


def get_audio_features(title):
    result_song= sp.search(q=title,type='track',limit=1)
    track = result_song['tracks']['items'][0]
    track_id = track['id']
    audio_features = sp.audio_features(track_id)[0]
    audio_features = json_normalize(audio_features)
    audio_features = audio_features.select_dtypes(include = np.number)
    scaled = scaler.transform(audio_features)
    audio_features = pd.DataFrame(scaled,columns=audio_features.columns)
    return audio_features

# %%
audio_features = get_audio_features('ziggy')

# %%
kmeans=pickle.load(open('/Users/damiencombe/Desktop/IH-Labs/Project files/kmeans_5.sav','rb'))

# %%
kmeans
# Out:
# KMeans(random_state=1234)

# %%
kmeans.predict(audio_features)
# Out:
# array([2], dtype=int32)

# %%
def get_cluster(title):
    get_audio_features(title)
    cluster = kmeans.predict(audio_features)
    return cluster[0]   #index to have a number because otherwise it's an array

# %%
get_cluster('ziggy')
# Out:
# 2

# %%
clustered_features = pd.read_pickle('/Users/damiencombe/Desktop/IH-Labs/Project files/clustered_features.pkl')

# %%
clustered_features
# Out:
#                            track.name                    name  \
# 0                Like a Rolling Stone               Bob Dylan
# 1             Smells Like Teen Spirit                 Nirvana
# 2      A Day In The Life - Remastered             The Beatles
# 3              Good Vibrations (Mono)          The Beach Boys
# 4                      Johnny B Goode             Chuck Berry
# ...                               ...                     ...
# 10925                 Into The Valley                   Skids
# 10926              Tonight's Da Night                  Redman
# 10927                        Figure 8               FKA twigs
# 10928                   Like An Angel  The Mighty Lemon Drops
# 10929                    Come Dancing               The Kinks
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      3AhXZa8sUQht0UEdBJgpGc         0.482   0.721    0    -6.839     1
# 1      3oTlkzk1OtrhH8wBAduVEi         0.485   0.863    1    -9.027     1
# 2      3ZFBeIyP41HhnALjxWy1pR         0.364   0.457    4   -14.162     0
# 3      5Qt4Cc66g24QWwGP3YYV9y         0.398   0.413    1   -10.934     1
# 4      7MH2ZclofPlTrZOkPzZKhK         0.518   0.756   10   -10.851     1
# ...                       ...           ...     ...  ...       ...   ...
# 10925  2QSD3K3b3BJ8DPhGhQfDPW         0.332   0.707    7   -12.698     1
# 10926  49XnDVsYOHgV4gFZeCojKj         0.464   0.749    6    -8.564     1
# 10927  5Y9IIH8Xmo1nuk0gfFjc4Q         0.694   0.710    2    -9.793     1
# 10928  0ya0JYEFoXNviB8RMeHDtW         0.332   0.800    1    -9.746     1
# 10929  32y1kRg6IF3f6jpkHxzFoK         0.499   0.763    7   -11.617     1
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.0321      0.731000  ...    0.1890    0.557   95.263
# 1           0.0495      0.000012  ...    0.1380    0.767  116.835
# 2           0.0675      0.290000  ...    0.9220    0.175  163.219
# 3           0.0388      0.082200  ...    0.0891    0.331  133.574
# 4           0.0915      0.735000  ...    0.3170    0.968  166.429
# ...            ...           ...  ...       ...      ...      ...
# 10925       0.0361      0.000012  ...    0.1100    0.652  144.815
# 10926       0.4800      0.224000  ...    0.3510    0.879  181.121
# 10927       0.3400      0.527000  ...    0.0697    0.415  119.964
# 10928       0.0326      0.000368  ...    0.0850    0.832  149.240
# 10929       0.0704      0.244000  ...    0.0828    0.895  152.677
#
#                  type                                   uri  \
# 0      audio_features  spotify:track:3AhXZa8sUQht0UEdBJgpGc
# 1      audio_features  spotify:track:3oTlkzk1OtrhH8wBAduVEi
# 2      audio_features  spotify:track:3ZFBeIyP41HhnALjxWy1pR
# 3      audio_features  spotify:track:5Qt4Cc66g24QWwGP3YYV9y
# 4      audio_features  spotify:track:7MH2ZclofPlTrZOkPzZKhK
# ...               ...                                   ...
# 10925  audio_features  spotify:track:2QSD3K3b3BJ8DPhGhQfDPW
# 10926  audio_features  spotify:track:49XnDVsYOHgV4gFZeCojKj
# 10927  audio_features  spotify:track:5Y9IIH8Xmo1nuk0gfFjc4Q
# 10928  audio_features  spotify:track:0ya0JYEFoXNviB8RMeHDtW
# 10929  audio_features  spotify:track:32y1kRg6IF3f6jpkHxzFoK
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3AhXZa8sUQht...
# 1      https://api.spotify.com/v1/tracks/3oTlkzk1Otrh...
# 2      https://api.spotify.com/v1/tracks/3ZFBeIyP41Hh...
# 3      https://api.spotify.com/v1/tracks/5Qt4Cc66g24Q...
# 4      https://api.spotify.com/v1/tracks/7MH2ZclofPlT...
# ...                                                  ...
# 10925  https://api.spotify.com/v1/tracks/2QSD3K3b3BJ8...
# 10926  https://api.spotify.com/v1/tracks/49XnDVsYOHgV...
# 10927  https://api.spotify.com/v1/tracks/5Y9IIH8Xmo1n...
# 10928  https://api.spotify.com/v1/tracks/0ya0JYEFoXNv...
# 10929  https://api.spotify.com/v1/tracks/32y1kRg6IF3f...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3AhX...      369600
# 1      https://api.spotify.com/v1/audio-analysis/3oTl...      300977
# 2      https://api.spotify.com/v1/audio-analysis/3ZFB...      337413
# 3      https://api.spotify.com/v1/audio-analysis/5Qt4...      219147
# 4      https://api.spotify.com/v1/audio-analysis/7MH2...      160893
# ...                                                  ...         ...
# 10925  https://api.spotify.com/v1/audio-analysis/2QSD...      199467
# 10926  https://api.spotify.com/v1/audio-analysis/49Xn...      201800
# 10927  https://api.spotify.com/v1/audio-analysis/5Y9I...      183040
# 10928  https://api.spotify.com/v1/audio-analysis/0ya0...      222160
# 10929  https://api.spotify.com/v1/audio-analysis/32y1...      234853
#
#        time_signature  cluster
# 0                   4        2
# 1                   4        2
# 2                   4        4
# 3                   4        4
# 4                   4        2
# ...               ...      ...
# 10925               4        4
# 10926               4        6
# 10927               4        6
# 10928               4        4
# 10929               4        2
#
# [10930 rows x 21 columns]

# %%
get_cluster('ziggy')
# Out:
# 2

# %%
from IPython.display import Markdown

import random
# pd.set_option("display.max_colwidth", max_characters)


def recommend(track):    
    # recommend songs from top hot songs
    if track in top_songs['title'].values:
        random_song = top_songs['title'][[random.randint(0, len(top_songs)-1)]].values[0]
        artist=top_songs['artist'][top_songs['title']==random_song].values[0]
        random_song=random_song.title()
        print("That's hot!")
        print("Here's another recommendation from Hot Right Now: "+random_song+ " by " +artist,'\n')
    
    # recommend songs based on audio features:
    # get the cluster value
    if (clustered_features['track.name'] == title).any():   #from the predictions we made using model on our playlist
        cluster=clustered_features['cluster'][clustered_features['track.name']==track].values[0]
        
    elif (clustered_features['track.name'] != title).any(): #using directly spotify api
        cluster= get_cluster(track)
        
    else:
        return 'No Recommendation!'
    
    # use the cluster value to get the songs which are clustered together
    # reset_index is important otherwise random.choice won't work
    recommend= clustered_features['track.name'][clustered_features['cluster']==cluster].reset_index(drop=True)
    
    # filter out the 'title' from recommendations
    filtered_recommend = recommend[recommend != title]

    # define 'random_track' with a default value
    random_track = None

    if len(filtered_recommend) > 0:
        random_track = random.choice(filtered_recommend)

    if random_track:
        artist = clustered_features.loc[clustered_features['track.name'] == random_track, 'name'].values[0]
        url = clustered_features.loc[clustered_features['track.name'] == random_track, 'song_id'].values[0]
        link = 'https://open.spotify.com/track/'+url
        print(f'If you like \'{title}\', you might also like \'{random_track}\' by {artist}.')
        display(Markdown(f"[Discover it now]({link})"))
    else:
        return 'No recommendations available.'

# %%
title = input('Please enter a song title: ').lower()
# Out:
# Please enter a song title: ziggy

# %%
recommend(title)
# Out:
# If you like 'ziggy', you might also like 'There's No Other Way - 2012 Remaster' by Blur.
# [Discover it now](https://open.spotify.com/track/7qk4uPeLpaKhp8lwas1sBb)
